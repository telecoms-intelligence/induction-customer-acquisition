# %%
# !ls -laFh ../data/
# Out:
# total 392K
# drwxrwxr-x 2 ubuntu ubuntu 4.0K Feb 11 13:56 ./
# drwxrwxr-x 6 ubuntu ubuntu 4.0K Feb 11 14:18 ../
# -rw-r--r-- 1 ubuntu ubuntu 382K Feb 11 13:12 conversion-rate-exploration.csv.bz2

# %%
import pandas as pd
data = pd.read_csv('../data/conversion-rate-exploration.csv.bz2', sep=';')

# %%
data
# Out:
#                           PJ_ID   pj_created_at recipient_details_gender  \
# 0      5qktitft6z5iwmhidall57go   5.2.2017 0:00                     Male
# 1      rmlwhcgf5nfnf6xf7ukzki3h   5.2.2017 0:00                     Male
# 2      ua7s4b2q5juco5glcdddiy4y   5.2.2017 0:00                     Male
# 3      ccz7qde5rtq2vdo7i6zbiwea   5.2.2017 0:00                     Male
# 4      2kl4dqgupwksxukebhh3dx4h   5.2.2017 0:00                     Male
# 5      exztimqdxbgdkfivw3ho7pz5   5.2.2017 0:00                     Male
# 6      awqzen4aed6ub3lgqyq4zb2l   5.2.2017 0:00                     Male
# 7      qdcungyb3w54hp3anbhd54os   5.2.2017 0:00                     Male
# 8      x7eqy3vrs5manm3h36pqrvhc   5.2.2017 0:00                     Male
# 9      37aez5h6mkg6kj6hhrhlvtx4   5.2.2017 0:00                     Male
# 10     m4xt6jenodneknwompoico4k   5.2.2017 0:00                     Male
# 11     7f3gvwidlct34wcy57yqbvav   5.2.2017 0:00                     Male
# 12     jdf4bspfittcprrmqt6yurpk   5.2.2017 0:00                     Male
# 13     r7w2jbr42fmtjcjwojo6pt3o   5.2.2017 0:00                     Male
# 14     ynokheeop2dbrck43k53ivyx   5.2.2017 0:00                     Male
# 15     4zttufzgeom2wgyxgsf6od4u   5.2.2017 0:00                     Male
# 16     g26f4pp6fa77qwgavtgkzwhf   5.2.2017 0:00                     Male
# 17     sjfer3xkbl5sspscj3gcj5s2   5.2.2017 0:00                     Male
# 18     wjr7g34tpvzt23voefdjgvsq   5.2.2017 0:00                     Male
# 19     mg4ylsxhe575saba6edu52tv   5.2.2017 0:00                     Male
# 20     mtu2z6u3ntrslrixh6w4y2it   5.2.2017 0:00                     Male
# 21     swzq36rzruufhsn6pin2umvz   5.2.2017 0:00                     Male
# 22     tro2mb6rvqgmdrcrovra2e3d   5.2.2017 0:00                     Male
# 23     plfja5n25r4lsnxr74o3k7u7   5.2.2017 0:00                     Male
# 24     qcaketiq43qawevvpwg5hdx6   5.2.2017 0:00                     Male
# 25     idw3fk7pz3ssrhotwd75dw4w   5.2.2017 0:00                     Male
# 26     ruq43huif5mijawzfxui3uls   5.2.2017 0:00                     Male
# 27     j5fhf4sdysus5vgux7pf7vni   5.2.2017 0:00                     Male
# 28     ossnuhcn2i2jgl6qigwwdn6m   5.2.2017 0:00                     Male
# 29     44vtub6rnescolmnbnlig37j   5.2.2017 0:00                     Male
# ...                         ...             ...                      ...
# 14003  wmloil7hjqvpmbqbdd4ps7br  9.28.2017 0:00                     Male
# 14004  v23xmxzu4jjkms35af4vu27d  9.28.2017 0:00                     Male
# 14005  cojrehjlhnbmpgxmkmhccakh  9.28.2017 0:00                     Male
# 14006  45rombuixwmc56kd6clarvjp  9.28.2017 0:00                     Male
# 14007  i6ffflpdi5n6w36ruzngazqf  9.28.2017 0:00                     Male
# 14008  7r425kpiu5wdtfmbydtnt2u7  9.28.2017 0:00                     Male
# 14009  5pj3k5xp7gpklw5q2srgtimt  9.28.2017 0:00                     Male
# 14010  5jm27url3beqdoss2567g4ls  9.28.2017 0:00                     Male
# 14011  oali7y4tgq7vjdeenofirdjh  9.28.2017 0:00                   Female
# 14012  5phezyru3qmai25f6lvhwoin  9.28.2017 0:00                     Male
# 14013  4jz6js3j4qxhrzyon66ebgdh  9.28.2017 0:00                     Male
# 14014  oasrhtcqmxlvamhmxpvnyx7c  9.28.2017 0:00                   Female
# 14015  wwsohsvokwtkhga6tfq5aqfv  9.28.2017 0:00                     Male
# 14016  xdyfkpmpoarkegutp2aec7ki  9.28.2017 0:00                     Male
# 14017  nz4b64viqtr5i6yigh5yxlfk  9.28.2017 0:00                     Male
# 14018  5amxd3j2qqtczwi3b3ur7czn  9.28.2017 0:00                     Male
# 14019  ylvy72zqu33jerj7lwfc4kpm  9.28.2017 0:00                     Male
# 14020  g65us7qhivtqiab4i6g7s5cw  9.28.2017 0:00                   Female
# 14021  6ktvy5nlo2xsga4kyyin7ow3  9.28.2017 0:00                     Male
# 14022  plrp5kuyqdu726jedpysqhjw  9.28.2017 0:00                     Male
# 14023  tgsgmjrmahip3vki4howttkp  9.28.2017 0:00                     Male
# 14024  agwrekmbzbacezjpoco44th3  9.28.2017 0:00                     Male
# 14025  f3da4lt3exzv6ymnd2upbqvo  9.28.2017 0:00                   Female
# 14026  e4dfj5pbi4avdnprdfzlegbu  9.28.2017 0:00                   Female
# 14027  5hgvc6cz53cf2yk3l7djgujb  9.28.2017 0:00                   Female
# 14028  fnayn6np7xg2gsdchmpexjgr  9.28.2017 0:00                     Male
# 14029  7vitn6abfgu3e7i3jkloje3e  9.28.2017 0:00                     Male
# 14030  ymeowlmvia46i5otx3hl626p  9.28.2017 0:00                     Male
# 14031  dt4hyfhyycra7m5n652x72r4  9.28.2017 0:00                     Male
# 14032  7cce3ie4lxjrsed5qgrhfir2  9.28.2017 0:00                     Male
#
#                             mpj first_device  first_os      first_browser  \
# 0                           NaN          NaN       NaN                NaN
# 1                           NaN          NaN       NaN                NaN
# 2                           NaN          NaN       NaN                NaN
# 3                           NaN          NaN       NaN                NaN
# 4                           NaN          NaN       NaN                NaN
# 5                           NaN          NaN       NaN                NaN
# 6                           NaN          NaN       NaN                NaN
# 7                           NaN          NaN       NaN                NaN
# 8                           NaN          NaN       NaN                NaN
# 9                           NaN          NaN       NaN                NaN
# 10                          NaN          NaN       NaN                NaN
# 11                          NaN          NaN       NaN                NaN
# 12                          NaN          NaN       NaN                NaN
# 13                          NaN          NaN       NaN                NaN
# 14                          NaN          NaN       NaN                NaN
# 15                          NaN          NaN       NaN                NaN
# 16                          NaN          NaN       NaN                NaN
# 17                          NaN          NaN       NaN                NaN
# 18                          NaN          NaN       NaN                NaN
# 19                          NaN          NaN       NaN                NaN
# 20                          NaN          NaN       NaN                NaN
# 21                          NaN          NaN       NaN                NaN
# 22                          NaN          NaN       NaN                NaN
# 23                          NaN          NaN       NaN                NaN
# 24                          NaN          NaN       NaN                NaN
# 25                          NaN          NaN       NaN                NaN
# 26                          NaN          NaN       NaN                NaN
# 27                          NaN          NaN       NaN                NaN
# 28                          NaN          NaN       NaN                NaN
# 29                          NaN          NaN       NaN                NaN
# ...                         ...          ...       ...                ...
# 14003  wmloil7hjqvpmbqbdd4ps7br      Android   Android             Chrome
# 14004  v23xmxzu4jjkms35af4vu27d      Android   Android             Chrome
# 14005  cojrehjlhnbmpgxmkmhccakh      Android   Android             Chrome
# 14006  45rombuixwmc56kd6clarvjp      Android   Android             Chrome
# 14007  i6ffflpdi5n6w36ruzngazqf      Android   Android             Chrome
# 14008  7r425kpiu5wdtfmbydtnt2u7      Android   Android             Chrome
# 14009  5pj3k5xp7gpklw5q2srgtimt      Desktop  Mac OS X            Firefox
# 14010  5jm27url3beqdoss2567g4ls      Desktop  Mac OS X             Chrome
# 14011  oali7y4tgq7vjdeenofirdjh      Desktop  Mac OS X             Safari
# 14012  5phezyru3qmai25f6lvhwoin      Desktop  Mac OS X             Safari
# 14013  4jz6js3j4qxhrzyon66ebgdh      Desktop  Mac OS X             Safari
# 14014  oasrhtcqmxlvamhmxpvnyx7c      Desktop   Windows              Opera
# 14015  wwsohsvokwtkhga6tfq5aqfv      Desktop   Windows     Microsoft Edge
# 14016  xdyfkpmpoarkegutp2aec7ki      Desktop   Windows     Microsoft Edge
# 14017  nz4b64viqtr5i6yigh5yxlfk      Desktop   Windows     Microsoft Edge
# 14018  5amxd3j2qqtczwi3b3ur7czn      Desktop   Windows  Internet Explorer
# 14019  ylvy72zqu33jerj7lwfc4kpm      Desktop   Windows  Internet Explorer
# 14020  g65us7qhivtqiab4i6g7s5cw      Desktop   Windows             Chrome
# 14021  6ktvy5nlo2xsga4kyyin7ow3      Desktop   Windows             Chrome
# 14022  plrp5kuyqdu726jedpysqhjw      Desktop   Windows             Chrome
# 14023  tgsgmjrmahip3vki4howttkp      Desktop   Windows             Chrome
# 14024  agwrekmbzbacezjpoco44th3      Desktop   Windows             Chrome
# 14025  f3da4lt3exzv6ymnd2upbqvo      Desktop   Windows            Firefox
# 14026  e4dfj5pbi4avdnprdfzlegbu      Desktop   Windows            Firefox
# 14027  5hgvc6cz53cf2yk3l7djgujb      Desktop   Windows            Firefox
# 14028  fnayn6np7xg2gsdchmpexjgr      Desktop   Windows            Firefox
# 14029  7vitn6abfgu3e7i3jkloje3e      Desktop   Windows            Firefox
# 14030  ymeowlmvia46i5otx3hl626p      Desktop   Windows            Firefox
# 14031  dt4hyfhyycra7m5n652x72r4      Desktop   Windows            Firefox
# 14032  7cce3ie4lxjrsed5qgrhfir2      Desktop   Windows            Firefox
#
#                   first_city last_device summarized_last_device    ...     \
# 0                        NaN         NaN                    NaN    ...
# 1                        NaN         NaN                    NaN    ...
# 2                        NaN         NaN                    NaN    ...
# 3                        NaN         NaN                    NaN    ...
# 4                        NaN         NaN                    NaN    ...
# 5                        NaN         NaN                    NaN    ...
# 6                        NaN         NaN                    NaN    ...
# 7                        NaN         NaN                    NaN    ...
# 8                        NaN         NaN                    NaN    ...
# 9                        NaN         NaN                    NaN    ...
# 10                       NaN         NaN                    NaN    ...
# 11                       NaN         NaN                    NaN    ...
# 12                       NaN         NaN                    NaN    ...
# 13                       NaN         NaN                    NaN    ...
# 14                       NaN         NaN                    NaN    ...
# 15                       NaN         NaN                    NaN    ...
# 16                       NaN         NaN                    NaN    ...
# 17                       NaN         NaN                    NaN    ...
# 18                       NaN         NaN                    NaN    ...
# 19                       NaN         NaN                    NaN    ...
# 20                       NaN         NaN                    NaN    ...
# 21                       NaN         NaN                    NaN    ...
# 22                       NaN         NaN                    NaN    ...
# 23                       NaN         NaN                    NaN    ...
# 24                       NaN         NaN                    NaN    ...
# 25                       NaN         NaN                    NaN    ...
# 26                       NaN         NaN                    NaN    ...
# 27                       NaN         NaN                    NaN    ...
# 28                       NaN         NaN                    NaN    ...
# 29                       NaN         NaN                    NaN    ...
# ...                      ...         ...                    ...    ...
# 14003                 Berlin     Android                 Mobile    ...
# 14004      Frankfurt am Main     Android                 Mobile    ...
# 14005                  Hürth     Android                 Mobile    ...
# 14006              Andernach     Android                 Mobile    ...
# 14007             Dusseldorf     Android                 Mobile    ...
# 14008                 Berlin     Desktop                Desktop    ...
# 14009                Giessen     Desktop                Desktop    ...
# 14010                 Berlin     Desktop                Desktop    ...
# 14011              Spremberg     Desktop                Desktop    ...
# 14012            Bad Homburg     Desktop                Desktop    ...
# 14013           Grevenbroich     Desktop                Desktop    ...
# 14014                  Gotha     Desktop                Desktop    ...
# 14015             Heidelberg     Desktop                Desktop    ...
# 14016             Heidelberg     Desktop                Desktop    ...
# 14017                 Berlin     Desktop                Desktop    ...
# 14018              Oberkirch     Desktop                Desktop    ...
# 14019                 Berlin     Desktop                Desktop    ...
# 14020              Wiesbaden     Desktop                Desktop    ...
# 14021                 Hilter     Desktop                Desktop    ...
# 14022                  Izmir     Desktop                Desktop    ...
# 14023               Walldorf     Desktop                Desktop    ...
# 14024           Angelbachtal     Desktop                Desktop    ...
# 14025       Hochheim am Main     Desktop                Desktop    ...
# 14026  Ludwigshafen am Rhein     Desktop                Desktop    ...
# 14027                Cologne     Desktop                Desktop    ...
# 14028              Nuremberg     Desktop                Desktop    ...
# 14029                Leipzig     Desktop                Desktop    ...
# 14030         Schackensleben     Desktop                Desktop    ...
# 14031                 Meppen     Desktop                Desktop    ...
# 14032             Dusseldorf     Desktop                Desktop    ...
#
#                    last_city video_viewed campaign_viewed   outcome  \
# 0                        NaN          NaN             NaN  Fallback
# 1                        NaN          NaN             NaN  Fallback
# 2                        NaN          NaN             NaN  Fallback
# 3                        NaN          NaN             NaN  Fallback
# 4                        NaN          NaN             NaN  Fallback
# 5                        NaN          NaN             NaN  Fallback
# 6                        NaN          NaN             NaN  Fallback
# 7                        NaN          NaN             NaN  Fallback
# 8                        NaN          NaN             NaN  Fallback
# 9                        NaN          NaN             NaN  Fallback
# 10                       NaN          NaN             NaN  Fallback
# 11                       NaN          NaN             NaN  Fallback
# 12                       NaN          NaN             NaN  Fallback
# 13                       NaN          NaN             NaN  Fallback
# 14                       NaN          NaN             NaN  Fallback
# 15                       NaN          NaN             NaN  Fallback
# 16                       NaN          NaN             NaN  Fallback
# 17                       NaN          NaN             NaN  Fallback
# 18                       NaN          NaN             NaN  Fallback
# 19                       NaN          NaN             NaN  Fallback
# 20                       NaN          NaN             NaN  Fallback
# 21                       NaN          NaN             NaN  Fallback
# 22                       NaN          NaN             NaN  Fallback
# 23                       NaN          NaN             NaN  Fallback
# 24                       NaN          NaN             NaN  Fallback
# 25                       NaN          NaN             NaN  Fallback
# 26                       NaN          NaN             NaN  Fallback
# 27                       NaN          NaN             NaN  Fallback
# 28                       NaN          NaN             NaN  Fallback
# 29                       NaN          NaN             NaN  Fallback
# ...                      ...          ...             ...       ...
# 14003                 Berlin          NaN             NaN    Payout
# 14004      Frankfurt am Main          NaN             NaN    Payout
# 14005             Dusseldorf          NaN             NaN    Payout
# 14006               Diepholz          NaN             NaN    Payout
# 14007             Dusseldorf          NaN             NaN    Payout
# 14008                 Berlin          NaN             NaN    Payout
# 14009                Giessen          NaN             NaN    Payout
# 14010                 Berlin          NaN             NaN    Payout
# 14011              Spremberg          NaN             NaN    Payout
# 14012            Bad Homburg          NaN             NaN    Payout
# 14013           Grevenbroich          NaN             NaN    Payout
# 14014                  Gotha          NaN             NaN    Payout
# 14015             Heidelberg          NaN             NaN    Payout
# 14016             Heidelberg          NaN             NaN    Payout
# 14017                 Berlin          NaN             NaN    Payout
# 14018              Oberkirch          NaN             NaN    Payout
# 14019                 Berlin          NaN             NaN    Payout
# 14020              Wiesbaden          NaN             NaN    Payout
# 14021                 Hilter          NaN             NaN    Payout
# 14022                  Izmir          NaN             NaN    Payout
# 14023               Walldorf          NaN             NaN    Payout
# 14024           Angelbachtal          NaN             NaN    Payout
# 14025       Hochheim am Main          NaN             NaN    Payout
# 14026  Ludwigshafen am Rhein          NaN             NaN    Payout
# 14027                Cologne          NaN             NaN    Payout
# 14028              Nuremberg          NaN             NaN    Payout
# 14029                Leipzig          NaN             NaN    Payout
# 14030         Schackensleben          NaN             NaN    Payout
# 14031                 Meppen          NaN             NaN    Payout
# 14032             Dusseldorf          NaN             NaN    Payout
#
#        conversion num_campaign_pages_looked  num_campaigns_looked  Closed  \
# 0               0                         0                     0     NaN
# 1               0                         0                     0     NaN
# 2               0                         0                     0     NaN
# 3               0                         0                     0     NaN
# 4               0                         0                     0     NaN
# 5               0                         0                     0     NaN
# 6               0                         0                     0     NaN
# 7               0                         0                     0     NaN
# 8               0                         0                     0     NaN
# 9               0                         0                     0     NaN
# 10              0                         0                     0     NaN
# 11              0                         0                     0     NaN
# 12              0                         0                     0     NaN
# 13              0                         0                     0     NaN
# 14              0                         0                     0     NaN
# 15              0                         0                     0     NaN
# 16              0                         0                     0     NaN
# 17              0                         0                     0     NaN
# 18              0                         0                     0     NaN
# 19              0                         0                     0     NaN
# 20              0                         0                     0     NaN
# 21              0                         0                     0     NaN
# 22              0                         0                     0     NaN
# 23              0                         0                     0     NaN
# 24              0                         0                     0     NaN
# 25              0                         0                     0     NaN
# 26              0                         0                     0     NaN
# 27              0                         0                     0     NaN
# 28              0                         0                     0     NaN
# 29              0                         0                     0     NaN
# ...           ...                       ...                   ...     ...
# 14003           0                         0                     0     1.0
# 14004           0                         0                     0     1.0
# 14005           0                         0                     0     1.0
# 14006           0                         0                     0     1.0
# 14007           0                         0                     0     1.0
# 14008           0                         0                     0     1.0
# 14009           0                         0                     0     1.0
# 14010           0                         0                     0     1.0
# 14011           0                         0                     0     1.0
# 14012           0                         0                     0     1.0
# 14013           0                         0                     0     1.0
# 14014           0                         0                     0     1.0
# 14015           0                         0                     0     1.0
# 14016           0                         0                     0     1.0
# 14017           0                         0                     0     1.0
# 14018           0                         0                     0     1.0
# 14019           0                         0                     0     1.0
# 14020           0                         0                     0     1.0
# 14021           0                         0                     0     1.0
# 14022           0                         0                     0     1.0
# 14023           0                         0                     0     1.0
# 14024           0                         0                     0     1.0
# 14025           0                         0                     0     1.0
# 14026           0                         0                     0     1.0
# 14027           0                         0                     0     1.0
# 14028           0                         0                     0     1.0
# 14029           0                         0                     0     1.0
# 14030           0                         0                     0     1.0
# 14031           0                         0                     0     1.0
# 14032           0                         0                     0     1.0
#
#        site visit  PJ count
# 0               0         1
# 1               0         1
# 2               0         1
# 3               0         1
# 4               0         1
# 5               0         1
# 6               0         1
# 7               0         1
# 8               0         1
# 9               0         1
# 10              0         1
# 11              0         1
# 12              0         1
# 13              0         1
# 14              0         1
# 15              0         1
# 16              0         1
# 17              0         1
# 18              0         1
# 19              0         1
# 20              0         1
# 21              0         1
# 22              0         1
# 23              0         1
# 24              0         1
# 25              0         1
# 26              0         1
# 27              0         1
# 28              0         1
# 29              0         1
# ...           ...       ...
# 14003           1         1
# 14004           1         1
# 14005           1         1
# 14006           1         1
# 14007           1         1
# 14008           1         1
# 14009           1         1
# 14010           1         1
# 14011           1         1
# 14012           1         1
# 14013           1         1
# 14014           1         1
# 14015           1         1
# 14016           1         1
# 14017           1         1
# 14018           1         1
# 14019           1         1
# 14020           1         1
# 14021           1         1
# 14022           1         1
# 14023           1         1
# 14024           1         1
# 14025           1         1
# 14026           1         1
# 14027           1         1
# 14028           1         1
# 14029           1         1
# 14030           1         1
# 14031           1         1
# 14032           1         1
#
# [14033 rows x 22 columns]

# %%
# Is the data clean -
# Are there duplicate PJ_IDs?
unique_PJ_ID = data.groupby('PJ_ID').agg({'pj_created_at': 'max'})
if (len(data) == len(unique_PJ_ID)):
    print('PJ_ID is unique')
else:
    print('PJ_ID is not unique. Please clean data.')
# Out:
# PJ_ID is unique

# %%
# Is the data clean -
# Is the mpj unique for every PJ if he clicked on the invitation email
unique_mpj = data.groupby('mpj').agg({'PJ_ID': 'nunique'})
if len(unique_mpj[unique_mpj['PJ_ID'] !=1]) == 0:
        print('mpj is unique')
else:
    print('mpj is not unique. Please clean data.')
# Out:
# mpj is unique

# %%
# Is the data clean
# Is the dataset with customer who did not visit the site clean ?
no_visits =  data[data['site visit'] == 0]
tmp = no_visits.groupby([no_visits.columns[15]]).agg({'PJ_ID': 'nunique'})
print(tmp)
tmp = no_visits.groupby([no_visits.columns[16]]).agg({'PJ_ID': 'nunique'})
print(tmp)
# How potential targets are converting without visiting the site ?
# Out:
#              PJ_ID
# outcome
# Combination     16
# Fallback      3450
# Payout         815
# Voucher         37
#             PJ_ID
# conversion
# 0            4265
# 1              53

# %%
# Conversion statistics by two variables (outcome, gender) on non site visit data (suspicious)
no_visits_group = no_visits.groupby(['outcome', 'recipient_details_gender']).agg({'conversion':'sum'})
no_visits_group
# Conclusion - Not sure how people who do not visit the site gets converted. Needs more exploration with business.
# Out:
#                                       conversion
# outcome     recipient_details_gender
# Combination Female                             2
#             Male                              14
# Fallback    Female                             0
#             Male                               0
# Payout      Female                             0
#             Male                               0
# Voucher     Female                             6
#             Male                              30

# %%
# Analysis
# Data ready
visits =  data[data['site visit'] == 1]

# %%
# Hypothesis 1: There is a sweet spot made of right combination of campaigns looked and campaign pages landed that gets converted.
visit_campaign_c = visits[(visits['conversion']==1)].groupby(['num_campaign_pages_looked','num_campaigns_looked']).agg({'conversion':'sum', 'Closed':'sum'}).reset_index()
visit_campaign_c.columns = ['num_campaign_pages_looked', 'num_campaigns_looked', 'conversion','closed']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.ylim((0,20))
plt.xlim((0,30))
plt.xlabel('Num_camp pages seen by converted users', fontsize=18)
plt.ylabel('Num_camps seen by converted users', fontsize=18)
plt.scatter(visit_campaign_c.num_campaign_pages_looked, visit_campaign_c.num_campaigns_looked
, s=visit_campaign_c.conversion)
# Conclusion, The propsensity to get converted decreases if the user has been not converted in 5 campaign page views.

# %%
#The same plot for people who visit but do not convert
visit_campaign_nc = visits[visits['conversion']==0].groupby(['num_campaign_pages_looked','num_campaigns_looked']).agg({'conversion':'count', 'Closed':'sum'}).reset_index()
visit_campaign_nc.columns = ['num_campaign_pages_looked', 'num_campaigns_looked', 'conversion','closed']

# %%
plt.ylim((0,20))
plt.xlim((0,30))
plt.xlabel('Num_camp_pages seen by non_cnvrtd users', fontsize=18)
plt.ylabel('Num_camps seen by non cnvrtd users', fontsize=18)
plt.scatter(visit_campaign_nc.num_campaign_pages_looked, visit_campaign_nc.num_campaigns_looked
, s=visit_campaign_nc.conversion)
# Conclusion, if the user has not converted in 2 views, and then data suddenly disappearing could mean that larger that 2 exposure lead to conversion.
# Hence optimum number of views is between 2 and 5. To improve the product we should try to reach that KPI.

# %%
# Hypothesis 2: Video plays an important role 
# Making the same graph on people who never saw the video
visit_campaign_v = visits[(visits['video_viewed'] == 1) & (visits['conversion'] == 1)].groupby(['num_campaign_pages_looked','num_campaigns_looked']).agg({'conversion':'sum', 'Closed':'sum'}).reset_index()
visit_campaign_v.columns = ['num_campaign_pages_looked', 'num_campaigns_looked', 'conversion','closed']

# %%
plt.ylim((0,20))
plt.xlim((0,30))
plt.xlabel('Num_camp pages seen by video watching users', fontsize=18)
plt.ylabel('Num_camps seen by video watching users', fontsize=18)
plt.scatter(visit_campaign_v.num_campaign_pages_looked, visit_campaign_v.num_campaigns_looked
, s=visit_campaign_v.conversion)

# %%
data_fltd = data[['mpj', 'pj_created_at', 'num_campaigns_looked', 'num_campaign_pages_looked', 'video_viewed', 'outcome', 'conversion']]
data_fltd['video_viewed'].fillna(0, inplace = True)
data_fltd
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pandas/core/generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#                             mpj pj_created_at  num_campaigns_looked  \
# 0                           NaN    2017-05-02                     0
# 1                           NaN    2017-05-02                     0
# 2                           NaN    2017-05-02                     0
# 3                           NaN    2017-05-02                     0
# 4                           NaN    2017-05-02                     0
# 5                           NaN    2017-05-02                     0
# 6                           NaN    2017-05-02                     0
# 7                           NaN    2017-05-02                     0
# 8                           NaN    2017-05-02                     0
# 9                           NaN    2017-05-02                     0
# 10                          NaN    2017-05-02                     0
# 11                          NaN    2017-05-02                     0
# 12                          NaN    2017-05-02                     0
# 13                          NaN    2017-05-02                     0
# 14                          NaN    2017-05-02                     0
# 15                          NaN    2017-05-02                     0
# 16                          NaN    2017-05-02                     0
# 17                          NaN    2017-05-02                     0
# 18                          NaN    2017-05-02                     0
# 19                          NaN    2017-05-02                     0
# 20                          NaN    2017-05-02                     0
# 21                          NaN    2017-05-02                     0
# 22                          NaN    2017-05-02                     0
# 23                          NaN    2017-05-02                     0
# 24                          NaN    2017-05-02                     0
# 25                          NaN    2017-05-02                     0
# 26                          NaN    2017-05-02                     0
# 27                          NaN    2017-05-02                     0
# 28                          NaN    2017-05-02                     0
# 29                          NaN    2017-05-02                     0
# ...                         ...           ...                   ...
# 14003  wmloil7hjqvpmbqbdd4ps7br    2017-09-28                     0
# 14004  v23xmxzu4jjkms35af4vu27d    2017-09-28                     0
# 14005  cojrehjlhnbmpgxmkmhccakh    2017-09-28                     0
# 14006  45rombuixwmc56kd6clarvjp    2017-09-28                     0
# 14007  i6ffflpdi5n6w36ruzngazqf    2017-09-28                     0
# 14008  7r425kpiu5wdtfmbydtnt2u7    2017-09-28                     0
# 14009  5pj3k5xp7gpklw5q2srgtimt    2017-09-28                     0
# 14010  5jm27url3beqdoss2567g4ls    2017-09-28                     0
# 14011  oali7y4tgq7vjdeenofirdjh    2017-09-28                     0
# 14012  5phezyru3qmai25f6lvhwoin    2017-09-28                     0
# 14013  4jz6js3j4qxhrzyon66ebgdh    2017-09-28                     0
# 14014  oasrhtcqmxlvamhmxpvnyx7c    2017-09-28                     0
# 14015  wwsohsvokwtkhga6tfq5aqfv    2017-09-28                     0
# 14016  xdyfkpmpoarkegutp2aec7ki    2017-09-28                     0
# 14017  nz4b64viqtr5i6yigh5yxlfk    2017-09-28                     0
# 14018  5amxd3j2qqtczwi3b3ur7czn    2017-09-28                     0
# 14019  ylvy72zqu33jerj7lwfc4kpm    2017-09-28                     0
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                          NaN
# 27                          NaN
# 28                          NaN
# 29                          NaN
# ...                         ...
# 14003                       NaN
# 14004                       NaN
# 14005                       NaN
# 14006                       NaN
# 14007                       NaN
# 14008                       NaN
# 14009                       NaN
# 14010                       NaN
# 14011                       NaN
# 14012                       NaN
# 14013                       NaN
# 14014                       NaN
# 14015                       NaN
# 14016                       NaN
# 14017                       NaN
# 14018                       NaN
# 14019                       NaN
# 14020                       NaN
# 14021                       NaN
# 14022                       NaN
# 14023                       NaN
# 14024                       NaN
# 14025                       NaN
# 14026                       NaN
# 14027                       NaN
# 14028                       NaN
# 14029                       NaN
# 14030                       NaN
# 14031                       NaN
# 14032                       NaN
#
# [14033 rows x 8 columns]

# %%
data_fltd[data_fltd['conversion'] == 0]['outcome'].unique()
# Out:
# array(['Fallback', 'Payout'], dtype=object)

# %%
# Users seeing any campaign are assigned a ``mpj`` ID
tmp = data[(data['num_campaigns_looked'] != 0) & (data['mpj'].isnull())]
tmp
# Out:
# Empty DataFrame
# Columns: [PJ_ID, pj_created_at, recipient_details_gender, mpj, first_device, first_os, first_browser, first_city, last_device, summarized_last_device, last_os, last_browser, last_city, video_viewed, campaign_viewed, outcome, conversion, num_campaign_pages_looked, num_campaigns_looked, Closed, site visit, PJ count, num_avg_campaigns_looked]
# Index: []
#
# [0 rows x 23 columns]

# %%
# Time-lines for converted customers
agg_visits_converted = data_fltd[data_fltd['conversion'] == 1].groupby(['pj_created_at'], as_index = False).sum()
agg_visits_converted
# Out:
#    pj_created_at  num_campaigns_looked  num_campaign_pages_looked  \
# 0     2017-05-02                    36                         80
# 1     2017-05-04                    33                         65
# 2     2017-05-09                    52                         99
# 3     2017-05-11                    12                         16
# 4     2017-05-16                     9                         16
# 5     2017-05-18                    12                         21
# 6     2017-05-23                    22                         43
# 7     2017-05-30                    60                        107
# 8     2017-05-31                     7                          8
# 9     2017-06-01                    22                         31
# 10    2017-06-06                    52                         87
# 11    2017-06-08                    31                         54
# 12    2017-06-13                    46                         97
# 13    2017-06-20                    20                         40
# 14    2017-06-21                    25                         40
# 15    2017-06-22                    11                         18
# 16    2017-06-23                    10                         21
# 17    2017-06-28                    43                         93
# 18    2017-06-30                    24                         41
# 19    2017-07-05                    92                        191
# 20    2017-07-07                     5                          8
# 21    2017-07-12                    37                         64
# 22    2017-07-14                    21                         46
# 23    2017-07-19                    24                         57
# 24    2017-07-21                    42                         95
# 25    2017-07-26                    24                         57
# 26    2017-07-28                    25                         36
# 27    2017-08-02                    35                         75
# 28    2017-08-04                    23                         33
# 29    2017-08-08                    21                         41
# 30    2017-08-10                     6                         10
# 31    2017-08-15                    12                         23
# 32    2017-08-17                     7                         10
# 33    2017-08-22                    28                         55
# 34    2017-08-23                     3                          7
# 35    2017-08-24                     5                         12
# 36    2017-08-29                    54                         94
# 37    2017-08-31                     9                         11
# 38    2017-09-05                    50                        104
# 39    2017-09-07                    23                         42
# 40    2017-09-12                    44                         78
# 41    2017-09-14                    39                         60
# 42    2017-09-15                     6                         28
# 43    2017-09-19                    11                         21
# 44    2017-09-21                    43                         69
# 45    2017-09-26                    47                        113
# 46    2017-09-27                    12                         24
# 47    2017-09-28                    23                         43
#
#     video_viewed  conversion  num_avg_campaigns_looked
# 0            1.0          18                 31.761905
# 1            0.0          12                 22.708333
# 2            0.0          22                 44.523810
# 3            0.0           5                  6.700000
# 4            0.0           7                 10.500000
# 5            0.0           6                 10.166667
# 6            0.0          14                 22.500000
# 7            0.0          24                 46.965368
# 8            0.0           3                  3.250000
# 9            0.0          10                 13.750000
# 10           0.0          24                 36.600000
# 11           0.0          11                 16.034848
# 12           0.0          16                 30.289216
# 13           0.0          10                 20.450000
# 14           0.0           9                 12.516667
# 15           0.0           7                  9.166667
# 16           0.0           5                  7.833333
# 17           1.0          23                 42.642857
# 18           0.0           7                 11.750000
# 19           3.0          44                 75.886905
# 20           0.0           2                  2.750000
# 21           1.0          14                 24.311111
# 22           0.0          10                 23.166667
# 23           1.0          12                 21.625000
# 24           0.0          13                 28.991667
# 25           0.0           9                 18.433333
# 26           0.0          11                  8.575000
# 27           0.0          17                 25.075000
# 28           0.0          12                 15.166667
# 29           0.0          12                 22.250000
# 30           0.0           3                  5.000000
# 31           0.0           7                 10.333333
# 32           0.0           5                  5.666667
# 33           1.0          14                 22.583333
# 34           0.0           3                  4.000000
# 35           0.0           4                  9.500000
# 36           0.0          17                 26.533333
# 37           2.0           3                  3.285714
# 38           1.0          25                 46.683333
# 39           0.0          10                 22.111111
# 40           0.0          20                 25.714286
# 41           2.0          13                 19.031579
# 42           0.0           3                 10.666667
# 43           0.0           7                 11.666667
# 44           0.0          15                 23.166667
# 45           2.0          16                 34.214286
# 46           0.0           8                 12.333333
# 47           1.0           8                 13.916667

# %%
# Time-lines for non converted customers
agg_visits_nonconverted = data_fltd[data_fltd['conversion'] == 0].groupby(['pj_created_at'], as_index = False).sum()
agg_visits_nonconverted
# Out:
#    pj_created_at  num_campaigns_looked  num_campaign_pages_looked  \
# 0     2017-05-02                    77                         96
# 1     2017-05-04                    89                        108
# 2     2017-05-09                   144                        196
# 3     2017-05-11                    33                         48
# 4     2017-05-16                    78                        102
# 5     2017-05-18                    36                         44
# 6     2017-05-23                    57                         68
# 7     2017-05-30                   137                        169
# 8     2017-05-31                    12                         12
# 9     2017-06-01                    65                         83
# 10    2017-06-06                    87                        105
# 11    2017-06-08                    31                         32
# 12    2017-06-13                   125                        162
# 13    2017-06-20                    34                         41
# 14    2017-06-21                    47                         55
# 15    2017-06-22                    17                         18
# 16    2017-06-23                    38                         47
# 17    2017-06-28                    71                         78
# 18    2017-06-30                    42                         46
# 19    2017-07-05                   158                        191
# 20    2017-07-07                    19                         22
# 21    2017-07-12                    98                        127
# 22    2017-07-14                    71                         88
# 23    2017-07-19                    62                         77
# 24    2017-07-21                    68                         93
# 25    2017-07-26                    66                         77
# 26    2017-07-28                    40                         43
# 27    2017-08-02                   103                        136
# 28    2017-08-04                    61                         78
# 29    2017-08-08                    82                         97
# 30    2017-08-10                    10                         11
# 31    2017-08-15                    38                         57
# 32    2017-08-17                    30                         40
# 33    2017-08-22                    99                        119
# 34    2017-08-23                    20                         22
# 35    2017-08-24                    14                         19
# 36    2017-08-29                    99                        123
# 37    2017-08-31                    21                         24
# 38    2017-09-05                   125                        145
# 39    2017-09-06                     0                          0
# 40    2017-09-07                    65                         71
# 41    2017-09-12                   100                        116
# 42    2017-09-14                    64                         92
# 43    2017-09-15                     8                          8
# 44    2017-09-19                    62                         73
# 45    2017-09-21                    53                         71
# 46    2017-09-26                    84                        102
# 47    2017-09-27                    33                         36
# 48    2017-09-28                    34                         43
#
#     video_viewed  conversion  num_avg_campaigns_looked
# 0            4.0           0                 47.307143
# 1            2.0           0                 55.459524
# 2            6.0           0                 92.444048
# 3            4.0           0                 32.333333
# 4            0.0           0                 52.476190
# 5            0.0           0                 21.000000
# 6            0.0           0                 48.833333
# 7            0.0           0                 79.144444
# 8            0.0           0                  6.000000
# 9            0.0           0                 39.800000
# 10           0.0           0                 56.958333
# 11           0.0           0                 22.000000
# 12           1.0           0                 78.209524
# 13           2.0           0                 24.600000
# 14           2.0           0                 30.916667
# 15           1.0           0                 10.333333
# 16           1.0           0                 27.166667
# 17           1.0           0                 37.104762
# 18           1.0           0                 31.666667
# 19           8.0           0                103.850000
# 20           1.0           0                 12.000000
# 21           3.0           0                 54.809524
# 22           2.0           0                 35.333333
# 23           3.0           0                 35.392857
# 24           3.0           0                 41.875000
# 25           2.0           0                 36.900000
# 26           3.0           0                 25.250000
# 27           2.0           0                 73.183333
# 28           1.0           0                 46.733333
# 29           3.0           0                 47.477778
# 30           3.0           0                  9.500000
# 31           2.0           0                 28.125000
# 32           3.0           0                 26.416667
# 33          15.0           0                 54.366667
# 34           3.0           0                 14.333333
# 35           5.0           0                 15.250000
# 36          10.0           0                 55.416667
# 37           7.0           0                 20.000000
# 38          30.0           0                 77.750000
# 39           0.0           0                       NaN
# 40          10.0           0                 35.000000
# 41           9.0           0                 68.250000
# 42           9.0           0                 45.416667
# 43           2.0           0                  5.000000
# 44           7.0           0                 41.400000
# 45          15.0           0                 35.866667
# 46          16.0           0                 68.916667
# 47           8.0           0                 23.500000
# 48           0.0           0                 21.976190

# %%
# Converted customers not having watched the video
ax = agg_visits_converted[agg_visits_converted['video_viewed'] == 0].plot (x = 'pj_created_at', y = 'num_campaigns_looked')
agg_visits_converted[agg_visits_converted['video_viewed'] == 0].plot (ax = ax, x = 'pj_created_at', y = 'num_campaign_pages_looked')
agg_visits_converted[agg_visits_converted['video_viewed'] == 0].plot (ax = ax, x = 'pj_created_at', y = 'conversion')

# %%
# Converted customers having watched the video
ax = agg_visits_converted[agg_visits_converted['video_viewed'] != 0].plot (x = 'pj_created_at', y = 'num_campaigns_looked')
agg_visits_converted[agg_visits_converted['video_viewed'] != 0].plot (ax = ax, x = 'pj_created_at', y = 'num_campaign_pages_looked')
agg_visits_converted[agg_visits_converted['video_viewed'] != 0].plot (ax = ax, x = 'pj_created_at', y = 'conversion')

# %%
# Non converted users having watched the video
ax = agg_visits_nonconverted[agg_visits_nonconverted['video_viewed'] != 0].plot (x = 'pj_created_at', y = 'num_campaigns_looked')
agg_visits_nonconverted[agg_visits_nonconverted['video_viewed'] != 0].plot (ax = ax, x = 'pj_created_at', y = 'num_campaign_pages_looked')
